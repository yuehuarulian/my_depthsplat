# %% [markdown]
# ```shell script
# python3 download_data.py [3dod/upsampling/raw] --split [Training/Validation] --video_id video_id1 video_id2 \
# --download_dir YOUR_DATA_FOLDER
#
# python3 download_data.py [3dod/upsampling/raw] --video_id_csv CSV_PATH \
# --download_dir YOUR_DATA_FOLDER
#
# ```
#
#
# ```bash
# python3 download_data.py raw --video_id_csv raw/test.csv --download_dir ../datasets/ARKitScenes/ --raw_dataset_assets lowres_wide.traj lowres_wide lowres_wide_intrinsics lowres_depth
# ```
# python3 download_data.py raw --video_id_csv raw/test.csv --download_dir ../datasets/ARKitScenes/ --raw_dataset_assets vga_wide vga_wide_intrinsics
#
# - mov：下载 iPhone ARKit 录制的视频，你可以用 ffmpeg 抽帧得到 RGB png
#
# - highres_depth / lowres_depth / confidence：高精度 FARO 深度、Apple LiDAR 低分辨率深度及其置信度。
#
# - lowres_wide_intrinsics、vga_wide_intrinsics：分别是 iPhone 主摄和副摄的相机内参。
#
# - lowres_wide.traj：低分辨率 LiDAR + 主摄的外参轨迹（时间戳对应视频帧）。
#
#
# wget -O model.ckpt https://huggingface.co/depth-anything/prompt-depth-anything-vitl/resolve/main/model.ckpt

# %%
import shutil
from pathlib import Path

path1 = Path("datasets/ARKitScenes/raw/Validation")
path2 = Path("datasets/ARKitScenes/raw/Training")

for scene_dir in path1.iterdir():
    if not scene_dir.is_dir():
        continue
    # 如过scene_dir下有vga_wide_intrinsics文件夹，删除
    # if (scene_dir / "vga_wide_intrinsics").exists():
    #     print(f"删除无效目录：{scene_dir.name}/vga_wide_intrinsics")
    #     shutil.rmtree(scene_dir / "vga_wide_intrinsics")
    # 如果目录下文件没有 lowres_depth 或者 wide_intrinsics 或者 wide 或者 lowres_wide.traj就删除整个目录
    if not any(scene_dir.glob("lowres_depth")) or \
       not any(scene_dir.glob("lowres_wide")) or \
       not any(scene_dir.glob("lowres_wide_intrinsics")) or \
       not any(scene_dir.glob("lowres_wide.traj")):
        print(f"删除无效场景：{scene_dir.name}")
        shutil.rmtree(scene_dir)
        continue

for scene_dir in path2.iterdir():
    if not scene_dir.is_dir():
        continue
    # 如过scene_dir下有vga_wide_intrinsics文件夹，删除
    # if (scene_dir / "vga_wide_intrinsics").exists():
    #     print(f"删除无效目录：{scene_dir.name}/vga_wide_intrinsics")
    #     shutil.rmtree(scene_dir / "vga_wide_intrinsics")
    if not any(scene_dir.glob("lowres_depth")) or \
       not any(scene_dir.glob("lowres_wide")) or \
       not any(scene_dir.glob("lowres_wide_intrinsics")) or \
       not any(scene_dir.glob("lowres_wide.traj")):
        print(f"删除无效场景：{scene_dir.name}")
        shutil.rmtree(scene_dir)
        continue
# Out:
# 删除无效场景：41069165
# 删除无效场景：41048071

# %%
import shutil
from pathlib import Path

root = Path("datasets/ARKitScenes")

# src_base = root / "raw" / "Validation"
# dst_base = root / "Validation"

src_base = root / "raw" / "Training"
dst_base = root / "Training"


for scene_dir in src_base.iterdir():
    if not scene_dir.is_dir():
        continue
    dst_dir = dst_base / scene_dir.name
    if not dst_dir.exists():
        continue

    # 遍历源目录下的所有文件/文件夹
    for item in scene_dir.iterdir():
        target = dst_dir / item.name
        if target.exists():
            print(f"跳过已存在: {target}")
            continue
        # 移动
        shutil.move(str(item), str(dst_dir))

    print(f"已处理场景：{scene_dir.name}")
# Out:
# 已处理场景：43896249
# 已处理场景：42898447
# 已处理场景：44796484
# 已处理场景：42899175
# 已处理场景：42897771
# 已处理场景：42897939
# 已处理场景：43649408
# 已处理场景：42898560
# 已处理场景：42899433
# 已处理场景：43828144
# 已处理场景：43896177
# 已处理场景：43649605
# 已处理场景：42444721
# 已处理场景：42898337
# 已处理场景：42897960
# 已处理场景：42899214
# 已处理场景：42898754
# 已处理场景：44796598
# 已处理场景：42897712
# 已处理场景：42899139
# 已处理场景：42898065
# 已处理场景：42898230
# 已处理场景：43649480
# 已处理场景：43828339
# 已处理场景：44358291
# 已处理场景：42897426
# 已处理场景：44796562
# 已处理场景：42899125
# 已处理场景：43896089
# 已处理场景：44796584
# 已处理场景：42445592
# 已处理场景：43828457
# 已处理场景：42898340
# 已处理场景：42445771
# 已处理场景：43649714
# 已处理场景：45260952
# 已处理场景：42899128
# 已处理场景：42445168
# 已处理场景：42898405
# 已处理场景：43649648
# 已处理场景：44358234
# 已处理场景：43649399
# 已处理场景：43896170
# 已处理场景：42899221
# 已处理场景：42444876
# 已处理场景：42899630
# 已处理场景：43828149
# 已处理场景：43649692
# 已处理场景：42899775
# 已处理场景：42445057
# 已处理场景：42898449
# 已处理场景：42447233
# 已处理场景：42445728
# 已处理场景：42899666
# 已处理场景：43895969
# 已处理场景：42899215
# 已处理场景：43828391
# 已处理场景：42897756
# 已处理场景：42447287
# 已处理场景：42899118
# 已处理场景：42898100
# 已处理场景：43649484
# 已处理场景：44796190
# 已处理场景：44796387
# 已处理场景：44796324
# 已处理场景：43649403
# 已处理场景：42445479
# 已处理场景：44358647
# 已处理场景：44796257
# 已处理场景：42447203
# 已处理场景：42897419
# 已处理场景：42445676
# 已处理场景：43649688
# 已处理场景：42898109
# 已处理场景：44358170
# 已处理场景：42899795
# 已处理场景：42897523
# 已处理场景：44358361
# 已处理场景：43828340
# 已处理场景：42899600
# 已处理场景：42898342
# 已处理场景：42447210
# 已处理场景：43649685
# 已处理场景：42898112
# 已处理场景：42897780
# 已处理场景：42446468
# 已处理场景：42444904
# 已处理场景：42899287
# 已处理场景：43828463
# 已处理场景：42898500
# 已处理场景：42444923
# 已处理场景：44358360
# 已处理场景：42445802
# 已处理场景：42899165
# 已处理场景：42898348
# 已处理场景：42445079
# 已处理场景：42445865
# 已处理场景：42923225
# 已处理场景：42445173
# 已处理场景：42899144
# 已处理场景：43649660
# 已处理场景：43828323
# 已处理场景：44796744
# 已处理场景：42444794
# 已处理场景：44358225
# 已处理场景：44358227
# 已处理场景：42899822
# 已处理场景：43828231
# 已处理场景：42446036
# 已处理场景：42446467
# 已处理场景：44796358
# 已处理场景：42897931
# 已处理场景：44358295
# 已处理场景：42897480
# 已处理场景：42899778
# 已处理场景：42445137
# 已处理场景：42897898
# 已处理场景：44358707
# 已处理场景：43828345
# 已处理场景：42899829
# 已处理场景：42898756
# 已处理场景：42444787
# 已处理场景：44358472
# 已处理场景：42899489
# 已处理场景：42898577
# 已处理场景：45260957
# 已处理场景：42898125
# 已处理场景：42447226
# 已处理场景：43828380
# 已处理场景：44358220
# 已处理场景：41048249
# 已处理场景：42445060
# 已处理场景：42897857
# 已处理场景：43828366
# 已处理场景：42899603
# 已处理场景：42899453
# 已处理场景：42898511
# 已处理场景：44358728
# 已处理场景：42444696
# 已处理场景：44796280
# 已处理场景：42446495
# 已处理场景：42899531
# 已处理场景：42444692
# 已处理场景：43896223
# 已处理场景：44358428
# 已处理场景：44358222
# 已处理场景：42445063
# 已处理场景：42444793
# 已处理场景：44358268
# 已处理场景：42444719
# 已处理场景：42444574
# 已处理场景：45261087
# 已处理场景：42445478
# 已处理场景：42445788
# 已处理场景：42444477
# 已处理场景：42444907
# 已处理场景：43649686
# 已处理场景：42899559
# 已处理场景：42444924
# 已处理场景：42899550
# 已处理场景：42445498
# 已处理场景：44358256
# 已处理场景：42899650
# 已处理场景：42445639
# 已处理场景：42444588
# 已处理场景：44796310
# 已处理场景：42897439
# 已处理场景：42444892
# 已处理场景：43649426
# 已处理场景：42445211
# 已处理场景：42898141
# 已处理场景：42445970
# 已处理场景：41048229
# 已处理场景：42444883
# 已处理场景：43649743
# 已处理场景：42445784
# 已处理场景：42899292
# 已处理场景：42899178
# 已处理场景：43828393
# 已处理场景：44796498
# 已处理场景：43649727
# 已处理场景：44796576
# 已处理场景：44796366
# 已处理场景：43828381
# 已处理场景：42445047
# 已处理场景：42898087
# 已处理场景：42898808
# 已处理场景：43828250
# 已处理场景：44796481
# 已处理场景：42899624
# 已处理场景：42897777
# 已处理场景：45260889
# 已处理场景：43828460
# 已处理场景：42899137
# 已处理场景：42444515
# 已处理场景：43649763
# 已处理场景：42446031
# 已处理场景：44796343
# 已处理场景：42445758
# 已处理场景：42446048
# 已处理场景：42923204
# 已处理场景：41048262
# 已处理场景：42444917
# 已处理场景：42445584
# 已处理场景：42444762
# 已处理场景：43896199
# 已处理场景：42898803
# 已处理场景：42444490
# 已处理场景：42897452
# 已处理场景：42445729
# 已处理场景：42444866
# 已处理场景：42446050
# 已处理场景：42445922
# 已处理场景：42897478
# 已处理场景：42445698
# 已处理场景：43828362
# 已处理场景：42898343
# 已处理场景：42898236
# 已处理场景：42897713
# 已处理场景：42898132
# 已处理场景：42445782
# 已处理场景：44358660
# 已处理场景：42445913
# 已处理场景：41048225
# 已处理场景：44796450
# 已处理场景：42899109
# 已处理场景：41048251
# 已处理场景：44796752
# 已处理场景：42899774
# 已处理场景：42444695
# 已处理场景：42444503
# 已处理场景：42897422
# 已处理场景：42445721
# 已处理场景：42899177
# 已处理场景：42899112
# 已处理场景：43649409
# 已处理场景：42898123
# 已处理场景：42898587
# 已处理场景：42445612
# 已处理场景：43828421
# 已处理场景：42897405
# 已处理场景：42898247
# 已处理场景：43649802
# 已处理场景：42445691
# 已处理场景：42447205
# 已处理场景：42897784
# 已处理场景：42899598
# 已处理场景：42444711
# 已处理场景：43649452
# 已处理场景：42445781
# 已处理场景：41048223
# 已处理场景：42898448
# 已处理场景：43649603
# 已处理场景：42446607
# 已处理场景：42444733
# 已处理场景：44796282
# 已处理场景：42445633
# 已处理场景：45260891
# 已处理场景：43649451
# 已处理场景：43828402
# 已处理场景：42444716
# 已处理场景：42899120
# 已处理场景：42897720
# 已处理场景：42898234
# 已处理场景：44796252
# 已处理场景：44796596
# 已处理场景：42444885
# 已处理场景：42445903
# 已处理场景：42444511
# 已处理场景：43649742
# 已处理场景：44358252
# 已处理场景：42898802
# 已处理场景：43649597
# 已处理场景：43649798
# 已处理场景：43828476
# 已处理场景：42445428
# 已处理场景：44358257
# 已处理场景：42898738
# 已处理场景：42899657
# 已处理场景：42444501
# 已处理场景：44796477
# 已处理场景：42898510
# 已处理场景：44358167
# 已处理场景：44358418
# 已处理场景：42897877
# 已处理场景：42897928
# 已处理场景：42446450
# 已处理场景：44796492
# 已处理场景：42444735
# 已处理场景：42898752
# 已处理场景：44358324
# 已处理场景：42897930
# 已处理场景：43828390
# 已处理场景：42897490
# 已处理场景：42445999
# 已处理场景：43828282
# 已处理场景：44358243
# 已处理场景：42923203
# 已处理场景：42444933
# 已处理场景：42445796
# 已处理场景：45260947
# 已处理场景：44358700
# 已处理场景：42445785
# 已处理场景：43649775
# 已处理场景：44358691
# 已处理场景：43828441
# 已处理场景：42898189
# 已处理场景：42897436
# 已处理场景：43896256
# 已处理场景：44796191
# 已处理场景：42447221
# 已处理场景：44358250
# 已处理场景：43828361
# 已处理场景：42444859
# 已处理场景：44796279
# 已处理场景：44358406
# 已处理场景：42446057
# 已处理场景：43896186
# 已处理场景：42899455
# 已处理场景：43649612
# 已处理场景：42447308
# 已处理场景：42899111
# 已处理场景：42898408
# 已处理场景：42897818
# 已处理场景：42444708
# 已处理场景：42899435
# 已处理场景：42445794
# 已处理场景：41048247
# 已处理场景：42445775
# 已处理场景：42446068
# 已处理场景：42445736
# 已处理场景：44358698
# 已处理场景：45261080
# 已处理场景：42898169
# 已处理场景：42447320
# 已处理场景：42899209
# 已处理场景：42897677
# 已处理场景：42899452
# 已处理场景：42445680
# 已处理场景：42898195
# 已处理场景：42898501
# 已处理场景：42899211
# 已处理场景：43896187
# 已处理场景：44796189
# 已处理场景：42897512
# 已处理场景：41048190
# 已处理场景：42897434
# 已处理场景：43649654
# 已处理场景：42445707
# 已处理场景：42897863
# 已处理场景：42444512
# 已处理场景：42899968
# 已处理场景：44796520
# 已处理场景：42897509
# 已处理场景：45260895
# 已处理场景：42444932
# 已处理场景：43649615
# 已处理场景：42446608
# 已处理场景：43828369
# 已处理场景：41048265
# 已处理场景：42898751
# 已处理场景：42445924
# 已处理场景：42445894
# 已处理场景：42445081
# 已处理场景：42899780
# 已处理场景：44358263
# 已处理场景：42898526
# 已处理场景：43649756
# 已处理场景：42444873
# 已处理场景：44796487
# 已处理场景：42897776
# 已处理场景：42899202
# 已处理场景：44796488
# 已处理场景：42898052
# 已处理场景：43828245
# 已处理场景：42897745
# 已处理场景：42897868
# 已处理场景：42899819
# 已处理场景：44796451
# 已处理场景：42898160
# 已处理场景：42923211
# 已处理场景：44796304
# 已处理场景：42899789
# 已处理场景：42445873
# 已处理场景：42898458
# 已处理场景：42897600
# 已处理场景：45261099
# 已处理场景：44796473
# 已处理场景：42446576
# 已处理场景：42446445
# 已处理场景：42923226
# 已处理场景：42897892
# 已处理场景：42444513
# 已处理场景：44358340
# 已处理场景：45261100
# 已处理场景：42898182
# 已处理场景：42899187
# 已处理场景：44796254
# 已处理场景：42898097
# 已处理场景：42445902
# 已处理场景：42897681
# 已处理场景：42445723
# 已处理场景：42445884
# 已处理场景：42444821
# 已处理场景：42445692
# 已处理场景：42897722
# 已处理场景：42446492
# 已处理场景：43896169
# 已处理场景：42444767
# 已处理场景：42899184
# 已处理场景：44796340
# 已处理场景：42897455
# 已处理场景：42445745
# 已处理场景：42899632
# 已处理场景：44358230
# 已处理场景：42445451
# 已处理场景：42444706
# 已处理场景：43649729
# 已处理场景：44796722
# 已处理场景：43649794
# 已处理场景：42445881
# 已处理场景：44358281
# 已处理场景：43828350
# 已处理场景：42444474
# 已处理场景：43649440
# 已处理场景：42445502
# 已处理场景：42899154
# 已处理场景：43828162
# 已处理场景：44358710
# 已处理场景：42897655
# 已处理场景：42444916
# 已处理场景：42898191
# 已处理场景：42899513
# 已处理场景：42899668
# 已处理场景：42445697
# 已处理场景：42445444
# 已处理场景：42897560
# 已处理场景：42898135
# 已处理场景：42898393
# 已处理场景：42445716
# 已处理场景：43828449
# 已处理场景：43649598
# 已处理场景：43649720
# 已处理场景：42899210
# 已处理场景：42898558
# 已处理场景：42445927
# 已处理场景：42897851
# 已处理场景：43649417
# 已处理场景：42444712
# 已处理场景：44796485
# 已处理场景：43649681
# 已处理场景：43649590
# 已处理场景：42897631
# 已处理场景：42444754
# 已处理场景：42899198
# 已处理场景：42897675
# 已处理场景：43896251
# 已处理场景：42445938
# 已处理场景：44358176
# 已处理场景：42899543
# 已处理场景：44796709
# 已处理场景：42445869
# 已处理场景：42446017
# 已处理场景：44358693
# 已处理场景：44358645
# 已处理场景：42899664
# 已处理场景：42445695
# 已处理场景：43828154
# 已处理场景：42447202
# 已处理场景：42444517
# 已处理场景：42899653
# 已处理场景：42899259
# 已处理场景：44358386
# 已处理场景：42897479
# 已处理场景：42899448
# 已处理场景：42897735
# 已处理场景：42444887
# 已处理场景：42898221
# 已处理场景：42899119
# 已处理场景：43649707
# 已处理场景：42446493
# 已处理场景：44358634
# 已处理场景：43828142
# 已处理场景：44796374
# 已处理场景：42445720
# 已处理场景：42898586
# 已处理场景：42445783
# 已处理场景：43649609
# 已处理场景：44358423
# 已处理场景：42897634
# 已处理场景：42445587
# 已处理场景：43828233
# 已处理场景：43649767
# 已处理场景：42445889
# 已处理场景：42898007
# 已处理场景：42445205
# 已处理场景：42897955
# 已处理场景：42898061
# 已处理场景：42898454
# 已处理场景：42445494
# 已处理场景：42445615
# 已处理场景：42445445
# 已处理场景：42445642
# 已处理场景：44358238
# 已处理场景：42445987
# 已处理场景：42899977
# 已处理场景：42898163
# 已处理场景：42897755
# 已处理场景：42899975
# 已处理场景：44796379
# 已处理场景：42897744
# 已处理场景：44358407
# 已处理场景：42899970
# 已处理场景：43895960
# 已处理场景：42445806
# 已处理场景：42444869
# 已处理场景：42445689
# 已处理场景：42445790
# 已处理场景：45260890
# 已处理场景：45260951
# 已处理场景：43649613
# 已处理场景：42899126
# 已处理场景：42445044
# 已处理场景：42898098
# 已处理场景：42444751
# 已处理场景：42445078
# 已处理场景：42445135
# 已处理场景：42899670
# 已处理场景：42445597
# 已处理场景：43828442
# 已处理场景：42898006
# 已处理场景：42898765
# 已处理场景：43649384
# 已处理场景：44358328
# 已处理场景：44358259
# 已处理场景：42898059
# 已处理场景：44358729
# 已处理场景：42444758
# 已处理场景：44796367
# 已处理场景：44796332
# 已处理场景：42445834
# 已处理场景：42444703
# 已处理场景：42447275
# 已处理场景：42447230
# 已处理场景：42898760
# 已处理场景：44358241
# 已处理场景：42445132
# 已处理场景：42446478
# 已处理场景：42444860
# 已处理场景：42446605
# 已处理场景：42897924
# 已处理场景：43896247
# 已处理场景：42897934
# 已处理场景：44796521
# 已处理场景：42898089
# 已处理场景：44796271
# 已处理场景：44796585
# 已处理场景：42899216
# 已处理场景：43649639
# 已处理场景：43649393
# 已处理场景：42444514
# 已处理场景：42899654
# 已处理场景：42444748
# 已处理场景：42897945
# 已处理场景：42897482
# 已处理场景：42898332
# 已处理场景：42445864
# 已处理场景：44796326
# 已处理场景：42899491
# 已处理场景：42899526
# 已处理场景：43896024
# 已处理场景：44796491
# 已处理场景：42897743
# 已处理场景：42445804
# 已处理场景：43896055
# 已处理场景：42898248
# 已处理场景：45260946
# 已处理场景：43828351
# 已处理场景：42898071
# 已处理场景：42445766
# 已处理场景：43828456
# 已处理场景：42899817
# 已处理场景：42899542
# 已处理场景：42897815
# 已处理场景：42898571
# 已处理场景：43828368
# 已处理场景：43649647
# 已处理场景：42898551
# 已处理场景：42446008
# 已处理场景：42447307
# 已处理场景：43649614
# 已处理场景：43649421
# 已处理场景：44358274
# 已处理场景：42445100
# 已处理场景：42445769
# 已处理场景：42898392
# 已处理场景：42923208
# 已处理场景：42923207
# 已处理场景：44358345
# 已处理场景：42898334
# 已处理场景：42445882
# 已处理场景：44358378
# 已处理场景：42445684
# 已处理场景：44796475
# 已处理场景：42898345
# 已处理场景：42447329
# 已处理场景：42444891
# 已处理场景：43649633
# 已处理场景：42899445
# 已处理场景：42444913
# 已处理场景：44358289
# 已处理场景：44796507
# 已处理场景：42898083
# 已处理场景：42897605
# 已处理场景：42444896
# 已处理场景：42447214
# 已处理场景：44358341
# 已处理场景：44358617
# 已处理场景：42444499
# 已处理场景：42445891
# 已处理场景：44358673
# 已处理场景：42446159
# 已处理场景：42897783
# 已处理场景：42444789
# 已处理场景：42899220
# 已处理场景：42444709
# 已处理场景：42898162
# 已处理场景：42444750
# 已处理场景：44796443
# 已处理场景：42897442
# 已处理场景：43649589
# 已处理场景：42897418
# 已处理场景：42899132
# 已处理场景：42445872
# 已处理场景：42445718
# 已处理场景：43828464
# 已处理场景：42444791
# 已处理场景：42898391
# 已处理场景：44796575
# 已处理场景：43828382
# 已处理场景：41048264
# 已处理场景：42898750
# 已处理场景：44358731
# 已处理场景：43896183
# 已处理场景：43649755
# 已处理场景：42444826
# 已处理场景：42899141
# 已处理场景：42445877
# 已处理场景：42444755
# 已处理场景：42899821
# 已处理场景：42897547
# 已处理场景：44796505
# 已处理场景：44358253
# 已处理场景：44796568
# 已处理场景：44358278
# 已处理场景：43649754
# 已处理场景：42444579
# 已处理场景：42898596
# 已处理场景：43649787
# 已处理场景：42897709
# 已处理场景：43895956
# 已处理场景：42899828
# 已处理场景：42446579
# 已处理场景：44358471
# 已处理场景：42446561
# 已处理场景：42444875
# 已处理场景：44358380
# 已处理场景：42444858
# 已处理场景：42898502
# 已处理场景：42446080
# 已处理场景：43828455
# 已处理场景：42899529
# 已处理场景：42897948
# 已处理场景：44358270
# 已处理场景：42898075
# 已处理场景：43649634
# 已处理场景：43896244
# 已处理场景：43649643
# 已处理场景：42898407
# 已处理场景：42444738
# 已处理场景：42899533
# 已处理场景：42899185
# 已处理场景：43649722
# 已处理场景：44796446
# 已处理场景：44796579
# 已处理场景：45261096
# 已处理场景：43649762
# 已处理场景：43828270
# 已处理场景：42445169
# 已处理场景：42446061
# 已处理场景：43649662
# 已处理场景：42446574
# 已处理场景：42445862
# 已处理场景：42899432
# 已处理场景：42445670
# 已处理场景：43828437
# 已处理场景：42445599
# 已处理场景：42445799
# 已处理场景：44358419
# 已处理场景：42447294
# 已处理场景：42898555
# 已处理场景：43828423
# 已处理场景：43649586
# 已处理场景：42898470
# 已处理场景：42445770
# 已处理场景：42445611
# 已处理场景：42447310
# 已处理场景：42897598
# 已处理场景：43649397
# 已处理场景：45260892
# 已处理场景：43828307
# 已处理场景：44358258
# 已处理场景：42445916
# 已处理场景：43896035
# 已处理场景：42445198
# 已处理场景：44796455
# 已处理场景：42897732
# 已处理场景：43649774
# 已处理场景：43649772
# 已处理场景：44358620
# 已处理场景：42447336
# 已处理场景：44796311
# 已处理场景：42898094
# 已处理场景：43649680
# 已处理场景：43649459
# 已处理场景：42897409
# 已处理场景：43649732
# 已处理场景：43896229
# 已处理场景：42445888
# 已处理场景：44796517
# 已处理场景：44796438
# 已处理场景：43896188
# 已处理场景：42898070
# 已处理场景：42898068
# 已处理场景：44358173
# 已处理场景：42898057
# 已处理场景：43649804
# 已处理场景：44358426
# 已处理场景：43828404
# 已处理场景：42444872
# 已处理场景：42444822
# 已处理场景：44358410
# 已处理场景：42897785
# 已处理场景：42445931
# 已处理场景：43828138
# 已处理场景：42897607
# 已处理场景：42899540
# 已处理场景：42446039
# 已处理场景：42899163
# 已处理场景：43896063
# 已处理场景：42897736
# 已处理场景：42897967
# 已处理场景：45261108
# 已处理场景：42899562
# 已处理场景：44358327
# 已处理场景：42898461
# 已处理场景：43649425
# 已处理场景：42444928
# 已处理场景：42898745
# 已处理场景：42897410
# 已处理场景：43828230
# 已处理场景：42898156
# 已处理场景：43649391
# 已处理场景：42899140
# 已处理场景：43828334
# 已处理场景：44796483
# 已处理场景：42898762
# 已处理场景：45261089
# 已处理场景：44358422
# 已处理场景：44358235
# 已处理场景：42897633
# 已处理场景：42446558
# 已处理场景：42898477
# 已处理场景：43828478
# 已处理场景：42897925
# 已处理场景：42447199
# 已处理场景：43828435
# 已处理场景：42898768

# %%
import json
import random
from pathlib import Path

# —— 1. 参数区 —— 
# 改成你本地路径
TRAIN_ROOT = Path("datasets/ARKitScenes/Training")

# 每个场景选择多少 context / target
NUM_CONTEXT = 2
NUM_TARGET  = 3
SEED = 42

random.seed(SEED)
eval_index = {}

for scene_dir in sorted(TRAIN_ROOT.iterdir()):
    if not scene_dir.is_dir():
        continue

    wide_dir = scene_dir / "wide"
    if not wide_dir.exists():
        eval_index[scene_dir.name] = None
        continue

    # 2) 提取 (timestamp, path) 对
    ts_frames = []
    for p in wide_dir.iterdir():
        if p.suffix.lower() not in (".png", ".jpg"):
            continue
        # 文件名格式：<videoID>_<timestamp>.png
        stem = p.stem  # "41048190_3644.288"
        try:
            ts = float(stem.split("_", 1)[1])
        except Exception:
            continue
        ts_frames.append((ts, p))

    # 3) 按时间戳排序
    ts_frames.sort(key=lambda x: x[0])
    n = len(ts_frames)
    if n < NUM_CONTEXT + NUM_TARGET:
        eval_index[scene_dir.name] = None
        continue

    # 4) 用排好序的索引来随机采样
    all_idx = list(range(n))
    context = sorted(random.sample(all_idx, NUM_CONTEXT))
    remaining = [i for i in all_idx if i not in context]
    target  = sorted(random.sample(remaining, NUM_TARGET))

    eval_index[scene_dir.name] = {
        "context": context,
        "target":  target,
    }

# 5) 写出 JSON
print(eval_index)
out_path = TRAIN_ROOT.parent / "train_index_acid.json"
with open(out_path, "w") as f:
    json.dump(eval_index, f)

print(f"✅ 完成：共处理 {len(eval_index)} 个场景，文件保存在 {out_path}")
# Out:
# {'41048190': {'context': [3, 14], 'target': [30, 33, 37]}, '41048223': {'context': [6, 8], 'target': [5, 36, 39]}, '41048225': {'context': [2, 27], 'target': [1, 6, 14]}, '41048229': {'context': [14, 32], 'target': [0, 18, 20]}, '41048247': {'context': [3, 5], 'target': [4, 6, 7]}, '41048249': {'context': [3, 7], 'target': [0, 2, 5]}, '41048251': None, '41048262': {'context': [20, 54], 'target': [19, 36, 44]}, '41048264': {'context': [27, 43], 'target': [11, 13, 50]}, '41048265': {'context': [12, 45], 'target': [34, 46, 79]}, '42444474': {'context': [1, 14], 'target': [4, 13, 19]}, '42444477': {'context': [5, 35], 'target': [19, 42, 55]}, '42444490': {'context': [23, 36], 'target': [2, 4, 12]}, '42444499': {'context': [3, 10], 'target': [1, 4, 5]}, '42444501': {'context': [3, 12], 'target': [9, 11, 16]}, '42444503': {'context': [11, 26], 'target': [5, 6, 12]}, '42444511': {'context': [4, 10], 'target': [1, 12, 13]}, '42444512': {'context': [9, 10], 'target': [2, 3, 8]}, '42444513': {'context': [5, 14], 'target': [9, 13, 22]}, '42444514': {'context': [17, 22], 'target': [7, 10, 23]}, '42444515': {'context': [0, 3], 'target': [1, 5, 7]}, '42444517': {'context': [1, 8], 'target': [4, 11, 13]}, '42444574': {'context': [6, 10], 'target': [14, 17, 22]}, '42444579': {'context': [4, 14], 'target': [2, 3, 9]}, '42444588': {'context': [17, 23], 'target': [8, 18, 25]}, '42444692': {'context': [13, 18], 'target': [11, 12, 20]}, '42444695': {'context': [4, 7], 'target': [2, 17, 18]}, '42444696': {'context': [1, 3], 'target': [6, 7, 22]}, '42444703': {'context': [4, 27], 'target': [25, 31, 35]}, '42444706': {'context': [8, 17], 'target': [0, 3, 23]}, '42444708': {'context': [21, 28], 'target': [8, 17, 25]}, '42444709': {'context': [20, 24], 'target': [3, 9, 10]}, '42444711': {'context': [5, 13], 'target': [0, 9, 16]}, '42444712': {'context': [5, 8], 'target': [1, 4, 12]}, '42444716': {'context': [40, 53], 'target': [12, 32, 38]}, '42444719': {'context': [4, 11], 'target': [6, 19, 26]}, '42444721': {'context': [16, 24], 'target': [0, 10, 20]}, '42444733': {'context': [0, 15], 'target': [4, 10, 12]}, '42444735': {'context': [1, 7], 'target': [3, 9, 19]}, '42444738': {'context': [2, 15], 'target': [9, 13, 16]}, '42444748': {'context': [4, 20], 'target': [6, 16, 18]}, '42444750': {'context': [8, 16], 'target': [6, 14, 19]}, '42444751': {'context': [19, 25], 'target': [11, 21, 22]}, '42444754': {'context': [14, 16], 'target': [3, 7, 15]}, '42444755': {'context': [2, 7], 'target': [0, 9, 12]}, '42444758': {'context': [7, 18], 'target': [0, 1, 2]}, '42444762': {'context': [2, 7], 'target': [1, 3, 12]}, '42444767': {'context': [7, 16], 'target': [8, 9, 11]}, '42444768': None, '42444787': {'context': [6, 17], 'target': [4, 8, 16]}, '42444789': {'context': [26, 30], 'target': [6, 12, 28]}, '42444791': {'context': [22, 27], 'target': [13, 14, 29]}, '42444793': {'context': [1, 3], 'target': [2, 8, 13]}, '42444794': {'context': [3, 10], 'target': [4, 8, 16]}, '42444821': {'context': [7, 8], 'target': [2, 6, 14]}, '42444822': {'context': [8, 14], 'target': [2, 7, 16]}, '42444826': {'context': [3, 17], 'target': [0, 1, 18]}, '42444858': {'context': [12, 14], 'target': [2, 3, 6]}, '42444859': None, '42444860': {'context': [15, 19], 'target': [1, 6, 12]}, '42444866': None, '42444869': None, '42444872': {'context': [2, 6], 'target': [0, 5, 8]}, '42444873': {'context': [9, 14], 'target': [15, 17, 19]}, '42444875': {'context': [2, 3], 'target': [0, 5, 6]}, '42444876': {'context': [0, 8], 'target': [1, 3, 6]}, '42444883': {'context': [1, 15], 'target': [0, 6, 9]}, '42444885': {'context': [2, 5], 'target': [1, 11, 16]}, '42444887': {'context': [7, 21], 'target': [3, 13, 19]}, '42444891': {'context': [2, 15], 'target': [3, 14, 21]}, '42444892': {'context': [18, 20], 'target': [8, 10, 16]}, '42444896': {'context': [6, 10], 'target': [8, 9, 14]}, '42444904': {'context': [4, 21], 'target': [10, 15, 22]}, '42444907': {'context': [2, 10], 'target': [0, 16, 20]}, '4244 ...
# ✅ 完成：共处理 1970 个场景，文件保存在 datasets/ARKitScenes/train_index_acid.json

# %%
import json
import random
from pathlib import Path

# —— 1. 参数区 —— 
TRAIN_ROOT = Path("datasets/ARKitScenes/Validation")

# 每个场景选择多少 context / target
NUM_CONTEXT = 2
NUM_TARGET  = 3
SEED = 42

random.seed(SEED)
eval_index = {}

for scene_dir in sorted(TRAIN_ROOT.iterdir()):
    if not scene_dir.is_dir():
        continue

    wide_dir = scene_dir / "wide"
    if not wide_dir.exists():
        eval_index[scene_dir.name] = None
        continue

    # 2) 提取 (timestamp, path) 对
    ts_frames = []
    for p in wide_dir.iterdir():
        if p.suffix.lower() not in (".png", ".jpg"):
            continue
        # 文件名格式：<videoID>_<timestamp>.png
        stem = p.stem  # "41048190_3644.288"
        try:
            ts = float(stem.split("_", 1)[1])
        except Exception:
            continue
        ts_frames.append((ts, p))

    # 3) 按时间戳排序
    ts_frames.sort(key=lambda x: x[0])
    n = len(ts_frames)
    if n < NUM_CONTEXT + NUM_TARGET:
        eval_index[scene_dir.name] = None
        continue

    # 4) 用排好序的索引来随机采样
    all_idx = list(range(n))
    context = sorted(random.sample(all_idx, NUM_CONTEXT))
    remaining = [i for i in all_idx if i not in context]
    target  = sorted(random.sample(remaining, NUM_TARGET))

    eval_index[scene_dir.name] = {
        "context": context,
        "target":  target,
    }

# 5) 写出 JSON
print(eval_index)
out_path = TRAIN_ROOT.parent / "test_index_acid.json"
with open(out_path, "w") as f:
    json.dump(eval_index, f)

print(f"✅ 完成：共处理 {len(eval_index)} 个场景，文件保存在 {out_path}")
# Out:
# {'41069021': {'context': [0, 3], 'target': [9, 10, 18]}, '41069025': {'context': [4, 23], 'target': [3, 22, 25]}, '41069042': {'context': [2, 17], 'target': [1, 14, 20]}, '41069043': {'context': [1, 5], 'target': [8, 9, 18]}, '41069046': {'context': [1, 35], 'target': [13, 15, 27]}, '41069048': {'context': [7, 9], 'target': [0, 4, 6]}, '41069050': {'context': [2, 5], 'target': [3, 4, 6]}, '41069051': {'context': [4, 6], 'target': [1, 3, 12]}, '41142278': {'context': [3, 12], 'target': [9, 13, 21]}, '41142280': {'context': [1, 14], 'target': [2, 7, 9]}, '41142281': {'context': [2, 17], 'target': [10, 21, 22]}, '42444946': {'context': [27, 28], 'target': [6, 11, 18]}, '42444949': {'context': [2, 22], 'target': [1, 8, 23]}, '42444950': {'context': [5, 18], 'target': [3, 8, 29]}, '42444966': {'context': [8, 12], 'target': [2, 13, 16]}, '42444968': {'context': [11, 18], 'target': [6, 8, 12]}, '42444976': {'context': [20, 21], 'target': [2, 5, 19]}, '42445021': {'context': [8, 11], 'target': [2, 3, 7]}, '42445022': {'context': [8, 12], 'target': [19, 22, 24]}, '42445026': {'context': [7, 10], 'target': [1, 8, 19]}, '42445028': {'context': [10, 12], 'target': [2, 6, 8]}, '42445029': {'context': [10, 18], 'target': [6, 13, 16]}, '42445031': {'context': [14, 20], 'target': [4, 7, 8]}, '42445429': {'context': [17, 23], 'target': [8, 18, 25]}, '42445441': {'context': [13, 18], 'target': [11, 12, 20]}, '42445448': {'context': [8, 14], 'target': [5, 33, 34]}, '42445991': {'context': [1, 3], 'target': [6, 7, 15]}, '42446038': {'context': [2, 19], 'target': [13, 15, 18]}, '42446049': {'context': [4, 7], 'target': [0, 2, 6]}, '42446100': {'context': [20, 24], 'target': [3, 9, 10]}, '42446103': {'context': [10, 27], 'target': [0, 15, 32]}, '42446114': {'context': [16, 32], 'target': [6, 11, 34]}, '42446156': {'context': [20, 27], 'target': [9, 21, 28]}, '42446163': {'context': [2, 6], 'target': [3, 7, 14]}, '42446165': {'context': [16, 17], 'target': [0, 7, 10]}, '42446167': {'context': [0, 1], 'target': [5, 6, 7]}, '42446517': {'context': [0, 3], 'target': [2, 11, 13]}, '42446519': {'context': [4, 31], 'target': [5, 18, 25]}, '42446522': {'context': [4, 15], 'target': [6, 9, 19]}, '42446527': {'context': [13, 16], 'target': [6, 8, 15]}, '42446529': {'context': [6, 9], 'target': [13, 14, 16]}, '42446532': {'context': [16, 28], 'target': [3, 7, 14]}, '42446533': {'context': [0, 1], 'target': [2, 4, 5]}, '42446535': {'context': [3, 9], 'target': [0, 1, 6]}, '42446536': {'context': [0, 5], 'target': [1, 2, 4]}, '42446540': {'context': [2, 10], 'target': [8, 9, 18]}, '42446541': {'context': [13, 31], 'target': [8, 32, 36]}, '42897501': {'context': [7, 15], 'target': [3, 6, 14]}, '42897504': {'context': [3, 21], 'target': [12, 14, 20]}, '42897508': {'context': [7, 13], 'target': [0, 12, 15]}, '42897521': {'context': [0, 1], 'target': [4, 5, 7]}, '42897526': {'context': [1, 3], 'target': [2, 6, 8]}, '42897528': {'context': [2, 7], 'target': [3, 5, 8]}, '42897541': {'context': [7, 14], 'target': [2, 16, 19]}, '42897542': {'context': [0, 4], 'target': [1, 2, 3]}, '42897545': {'context': [2, 3], 'target': [8, 9, 10]}, '42897549': {'context': [3, 6], 'target': [0, 2, 8]}, '42897550': {'context': [0, 12], 'target': [5, 14, 15]}, '42897552': {'context': [2, 3], 'target': [0, 5, 6]}, '42897554': {'context': [3, 4], 'target': [0, 1, 6]}, '42897559': {'context': [1, 17], 'target': [2, 11, 19]}, '42897561': {'context': [2, 7], 'target': [0, 5, 8]}, '42897564': {'context': [2, 13], 'target': [1, 10, 12]}, '42897566': {'context': [3, 10], 'target': [1, 5, 7]}, '42897599': {'context': [15, 37], 'target': [2, 40, 41]}, '42897647': {'context': [2, 13], 'target': [18, 20, 23]}, '42897651': {'context': [33, 40], 'target': [26, 87, 93]}, '42897667': {'context': [15, 20], 'target': [8, 17, 27]}, '42897688': {'context': [41, 42], 'target': [19, 20, 29]}, '42898811': {'context': [0, 2], 'target': [16, 20, 21]}, '42898816': {'context': [1, 12], 'target': [4, 9, 11]}, '42 ...
# ✅ 完成：共处理 287 个场景，文件保存在 datasets/ARKitScenes/test_index_acid.json

# %%
import torch

def inspect_checkpoint(path, show_shapes=True, show_summary=True, num=2):
    """
    加载并检查一个 PyTorch checkpoint 文件的内容。

    Args:
        path (str): checkpoint 文件路径（.pt/.pth）。
        show_shapes (bool): 是否打印每个参数的名字和形状。
        show_summary (bool): 是否打印参数总数统计。

    Returns:
        state_dict (dict): checkpoint 中实际加载的 state_dict。
    """
    # 1. 加载 checkpoint
    ckpt = torch.load(path, map_location="cpu")
    # 如果是包含 'state_dict' 的 dict，就提取它
    state_dict = ckpt.get("state_dict", ckpt)
    name = [x.split('.')[num] for x in state_dict.keys() if x.endswith("weight")]
    name = set(name)
    print(name)

    # 2. 打印所有参数名和形状
    if show_shapes:
        print(f"\n>>> Loaded {len(state_dict)} keys from '{path}':\n")
        for name, tensor in state_dict.items():
            print(f"  {name:<60} shape={tuple(tensor.shape)} dtype={tensor.dtype}")
    
    # 3. 汇总统计
    if show_summary:
        total_params = sum(t.numel() for t in state_dict.values())
        num_layers  = len(state_dict)
        print(f"\n>>> Summary:")
        print(f"    total layers/keys : {num_layers}")
        print(f"    total parameters  : {total_params:,}  ({total_params/1e6:.2f} M)\n")

    # return state_dict

inspect_checkpoint("pretrained/depthsplat-gs-small-re10k-256x256-view2-cfeab6b1.pth", show_shapes = False, show_summary = True)
# inspect_checkpoint("pretrained/depth-anything/model_s.ckpt", show_shapes = False, show_summary = True)
# Out:
# {'transformer', 'regressor', 'depth_head', 'concat_projects', '0', 'scratch', 'backbone', 'upsampler', 'projects', 'pretrained', 'resize_layers', '2', 'regressor_residual'}
#
# >>> Summary:
#     total layers/keys : 567
#     total parameters  : 38,346,416  (38.35 M)
# /tmp/ipykernel_321124/1304574720.py:16: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(path, map_location="cpu")

# %%
inspect_checkpoint("pretrained/depth-anything/model_s.ckpt", show_shapes = False, show_summary = True, num=1)
# Out:
# {'depth_head', 'pretrained'}
#
# >>> Summary:
#     total layers/keys : 265
#     total parameters  : 25,083,079  (25.08 M)
# /tmp/ipykernel_321124/1304574720.py:16: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(path, map_location="cpu")
